# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshdinz12/Machine_learning/blob/main/FACE_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
img_path = "/content/ai-generated-multi-ethnic-diverse-group-of-people-free-photo.jpg"

# %%
img = cv2.imread("/content/ai-generated-multi-ethnic-diverse-group-of-people-free-photo.jpg")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1470x980>
