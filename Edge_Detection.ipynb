# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshdinz12/Machine_learning/blob/main/Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path="/ai-generated-multi-ethnic-diverse-group-of-people-free-photo.jpg"

# %%
image=cv2.imread("/ai-generated-multi-ethnic-diverse-group-of-people-free-photo.jpg")

# %%
image_rgb=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.title("Original image")
plt.axis("off")
plt.show()

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image,cmap="gray")
plt.title("Grayscale image")
plt.axis("off")
plt.show()

# %%
blurred_image=cv2.GaussianBlur(gray_image,(5,5),0)

# %%
plt.imshow(blurred_image,cmap="gray")
plt.title("Blurred image")
plt.axis("off")
plt.show()

# %%
edges=cv2.Canny(blurred_image,50,150)

# %%
plt.imshow(edges,cmap="gray")
plt.title("Edge Detection")
plt.axis("off")
plt.show()
